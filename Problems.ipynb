# %% [markdown]
# ## Problem 1: Extending the Lady Tasting Tea
#
# In the original case, there were 8 cups (4 with tea and 4 with milk). Now, we have 12 cups
# (8 with tea and 4 with milk). One participant claims to be able to correctly identify
# which cups were served with tea first
#
# Use NumPy and estimate the probability
# of getting them all right by pure chance.

# %%
import numpy as np

# information for carrying out the experiment

cups = ['T']*8 + ['M']*4
n_sim =  100000


#'T'*8 represents 8 trials with a cup of tea
#'M'*4 represents 4 trials with a milk 
# n_sim = 100000 # number of simulations 

success = sum(
    np.random.permutation(cups).tolist() == ['T']*8 + ['M']*4  # count how many times tea cups are in the first 8 positions
    for _ in range(n_sim))  # repeat the simulation n_sim times

print(f"Probability of all tea cups in the first 8 positions: {success/n_sim:.3f}")
# Out:
# Probability of all tea cups in the first 8 positions: 0.002
